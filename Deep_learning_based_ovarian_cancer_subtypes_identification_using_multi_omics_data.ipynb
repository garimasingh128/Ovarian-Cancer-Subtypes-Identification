# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd
from sklearn.cluster import KMeans
import sklearn.metrics
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
#aaaa
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cd126494-3e29-4700-9d62-93dae0f57ef1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd126494-3e29-4700-9d62-93dae0f57ef1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving aaaa.csv to aaaa.csv

# %%
import io
data = pd.read_csv(io.BytesIO(uploaded['aaaa.csv']))

# %%
with open(r"aaaa.csv", 'r') as f:
    data = pd.read_csv(f)

# %%
tcga_input=np.transpose(data)
print(tcga_input.shape[1])
# Out:
# 99

# %%
clf = KMeans(n_clusters=2, random_state=5)
clf.fit(tcga_input)
centers = clf.cluster_centers_
labels = clf.labels_
print(centers)
silhouetteScore = silhouette_score(tcga_input, labels, metric='euclidean')
davies_bouldinScore = davies_bouldin_score(tcga_input, labels)
print("K-mean silhouette score: ",silhouetteScore)
print("K-mean DBI: ",davies_bouldinScore)
# Out:
# [[ 1.57672701e-01  5.22437496e-02  1.57672701e-01  5.22437496e-02
#   -5.08357480e-02 -1.56409018e-01 -3.43985765e-01 -1.57767772e-01
#   -1.57767772e-01  1.57718330e-01 -1.49399498e-01  1.53127449e-01
#    4.81526272e-01 -3.67846081e-02 -2.66125438e-01  6.98225373e-02
#    7.21321335e-02 -6.37845032e-02  1.04008151e-01  2.68624744e-01
#    1.88919515e-01 -1.96839770e-01  2.44201017e-03 -1.82437155e-02
#   -7.95850620e-02  3.43929890e-01 -1.64521944e-02  3.77787621e-01
#   -1.64521944e-02  2.26702927e-02 -3.30553142e-02  1.97292070e-01
#    6.06654368e-02  4.35941632e-01  1.97577666e-01  1.32853049e+00
#   -1.51528900e-03  1.41533135e-01  2.07083208e-01 -1.43623332e-01
#   -3.03931961e-01  6.97134342e-01  4.12069137e-02  2.36985629e-01
#   -1.65445783e-01  1.64399453e-01 -4.93167148e-02 -2.13280136e-01
#    5.83350837e-02 -1.33419842e-01  3.51187501e-01  3.21258037e-01
#    1.74365632e-01  1.92259091e-01  1.53854915e-01 -2.21947697e-02
# ...

# %%
plt.scatter(tcga_input[0], tcga_input[1])
print("shape of array :")
print(np.array(tcga_input).shape)
# Out:
# shape of array :
# (13, 99)

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-3f5b796b-8795-459e-b1b7-90cc79aa8d73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f5b796b-8795-459e-b1b7-90cc79aa8d73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving a.csv to a.csv

# %%
import io
d1 = pd.read_csv(io.BytesIO(upload['a.csv']))

# %%
with open(r"a.csv", 'r') as f1:
    d1 = pd.read_csv(f1)

# %%
t1=np.transpose(d1)
print(t1.shape[1])
# Out:
# 2145

# %%
clf1 = KMeans(n_clusters=2, random_state=5)
clf1.fit(t1)
centers1 = clf1.cluster_centers_
labels1 = clf1.labels_
print(centers1)
silhouetteScore1 = silhouette_score(t1, labels1, metric='euclidean')
davies_bouldinScore1 = davies_bouldin_score(t1, labels1)
print("K-mean silhouette score: ",silhouetteScore1)
print("K-mean DBI: ",davies_bouldinScore1)
# Out:
# [[-1.46920927 -1.541652   -1.62149073 ... -0.44001868  0.89714218
#   -0.4360791 ]
#  [-3.38       -3.44       -3.44       ... -4.21       -4.21
#   -4.21      ]]
# K-mean silhouette score:  0.48594779632184526
# K-mean DBI:  0.25044312459978557

# %%
print("shape of array :")
print(np.array(t1).shape)
# Out:
# shape of array :
# (5, 2145)

# %%
# a
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-639c15d9-116c-41c1-a791-1e81d9467128" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-639c15d9-116c-41c1-a791-1e81d9467128">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving a.csv to a.csv

# %%
import io
d1 = pd.read_csv(io.BytesIO(upload['a.csv']))

# %%
with open(r"a.csv", 'r') as f1:
    d1 = pd.read_csv(f1)

# %%
print(d1.shape)
# Out:
# (2145, 5)

# %%
d1.head()
# Out:
#       ap         p         t     B       lfc
# 0  0.996  0.000105 -6.168684 -3.38 -0.704258
# 1  0.996  0.000198 -5.694552 -3.44 -1.468254
# 2  0.996  0.000219 -5.624207 -3.44 -1.857974
# 3  0.996  0.000225 -5.602202 -3.45 -1.492281
# 4  0.996  0.000269  5.475223 -3.46  0.652245

# %%
for column in d1:
    unique_values = np.unique(d1[column])
    nr_values = len(unique_values)
    if nr_values <= 10:
        print("The number of values for feature {} is: {} -- {}".format(column, nr_values, unique_values))
    else:
        print("The number of values for feature {} is: {}".format(column, nr_values))
# Out:
# The number of values for feature ap is: 1 -- [0.996]
# The number of values for feature p is: 2091
# The number of values for feature t is: 2144
# The number of values for feature B is: 75
# The number of values for feature lfc is: 2145

# %%
import seaborn as sns
#To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function.
#This shows the relationship for (n,2) combination of variable in a DataFrame as a matrix of plots and the diagonal plots are the univariate plots.
g = sns.pairplot(d1)

# %%
d1.columns
# Out:
# Index(['ap', 'p', 't', 'B', 'lfc'], dtype='object')

# %%
features = ['ap', 'p', 't', 'B', 'lfc']

# %%
X = d1.drop('t', axis = 1).values
y = d1['t']
y = y.astype(int)
from sklearn.tree import DecisionTreeClassifier
print(X.shape)
print(y.shape)
clf = KMeans(n_clusters=2, random_state=5)
clf.fit(X, y)
# Out:
# (2145, 4)
# (2145,)
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=5, tol=0.0001, verbose=0)

# %%
fi_col = []
fi = []
#Feature importance refers to a class of techniques for assigning scores to input features to a 
#predictive model that indicates the relative importance of each feature when making a prediction.
for i,column in enumerate(d1.drop('t', axis = 1)):
    print('The feature importance for {} is : {}'.format(column, dt.feature_importances_[i]))
    
    fi_col.append(column)
    fi.append(dt.feature_importances_[i])

fi_col
fi

fi_df = zip(fi_col, fi)
fi_df = pd.DataFrame(fi_df, columns = ['Feature','Feature Importance'])
fi_df


# Ordering the data
fi_df = fi_df.sort_values('Feature Importance', ascending = False).reset_index()

# Creating columns to keep
columns_to_keep = fi_df['Feature'][0:40]

fi_df
# Out:
# The feature importance for ap is : 0.0
# The feature importance for p is : 0.5045349619299587
# The feature importance for B is : 0.0
# The feature importance for lfc is : 0.4954650380700413
#    index Feature  Feature Importance
# 0      1       p            0.504535
# 1      3     lfc            0.495465
# 2      0      ap            0.000000
# 3      2       B            0.000000

# %%
X = d1[columns_to_keep].values
X

y = d1['t']
y = y.astype(int)
y

print(X.shape)
print(y.shape)
# Out:
# (2145, 4)
# (2145,)

# %%
# Hold-out validation
from sklearn.model_selection import train_test_split
# first one
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, test_size=0.2, random_state=15)

# Second one
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size = 0.9, test_size=0.1, random_state=15)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)

print(y_train.shape)
print(y_test.shape)
print(y_valid.shape)
ax = sns.countplot(x = y_valid, palette = "Set3")
# Out:
# (1544, 4)
# (429, 4)
# (172, 4)
# (1544,)
# (429,)
# (172,)

# %%
log_reg = LogisticRegression(random_state=10, solver = 'lbfgs')

log_reg.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=10, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# predict - Predict class labels for samples in X
log_reg.predict(X_train)
y_pred = log_reg.predict(X_train)

# predict_proba - Probability estimates
pred_proba = log_reg.predict_proba(X_train)

# coef_ - Coefficient of the features in the decision function
log_reg.coef_
# score- Returns the mean accuracy on the given test data and labels - below
# Out:
# array([[-3.18954952e-02, -5.26815450e-01, -2.07020028e-03,
#          1.04592477e+00],
#        [-5.74861301e-02, -1.66991647e+00,  3.96777026e-01,
#          6.44342163e-01],
#        [-4.29799287e-01, -4.12757357e+00,  1.84451243e+00,
#          3.46511572e+00],
#        [-7.54762053e-01, -3.35498259e+00, -9.37875826e-01,
#          3.37098665e+00],
#        [ 1.34250119e+00, -3.48346946e+00, -1.51779277e+00,
#         -8.17921917e+00],
#        [ 1.00792620e+00,  3.73309651e+00, -4.90724131e-01,
#         -9.23267211e+00],
#        [-4.46494540e-01,  4.05644140e+00, -2.26617098e+00,
#          3.15158535e+00],
#        [-5.40106530e-01,  3.40285687e+00,  2.41978215e+00,
#          4.75423948e+00],
#        [-8.98833615e-02,  1.97036276e+00,  5.53562299e-01,
#          9.79697154e-01]])

# %%
# Accuracy on Train
print("The Training Accuracy is: ", log_reg.score(X_train, y_train))

# Accuracy on Test
print("The Testing Accuracy is: ", log_reg.score(X_test, y_test))

from sklearn.metrics import r2_score, explained_variance_score, confusion_matrix, accuracy_score, classification_report, log_loss

# Classification Report
print(classification_report(y_train, y_pred))
# Out:
# The Training Accuracy is:  0.8601036269430051
# The Testing Accuracy is:  0.8811188811188811
#               precision    recall  f1-score   support
#
#           -6       0.00      0.00      0.00         1
#           -5       0.00      0.00      0.00         3
#           -4       0.00      0.00      0.00        25
#           -3       0.72      0.53      0.61       139
#           -2       0.89      1.00      0.94       518
#            2       0.90      1.00      0.94       632
#            3       0.69      0.59      0.63       179
#            4       0.00      0.00      0.00        43
#            5       0.00      0.00      0.00         4
#
#     accuracy                           0.86      1544
#    macro avg       0.35      0.35      0.35      1544
# weighted avg       0.81      0.86      0.83      1544
# ...

# %%
#MODEL IN PAPER

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior() 
import numpy as np  
import matplotlib.pyplot as plt  
import pandas as pd
from sklearn.cluster import KMeans
import sklearn.metrics
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from sklearn.cluster import AgglomerativeClustering
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from google.colab import files
uploaded = files.upload()
# with open(r"simulation.csv", 'r') as f:
#     data = pd.read_csv(f)
# Out:
#      <input type="file" id="files-cfe70172-a78b-4138-a926-3d7bad6bdf4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cfe70172-a78b-4138-a926-3d7bad6bdf4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving simulation.csv to simulation.csv

# %%
import io
data = pd.read_csv(io.BytesIO(uploaded['simulation.csv']))

# %%
with open(r"simulation.csv", 'r') as f:
    data = pd.read_csv(f)

# %%
#print(data.shape)
tcga_input=np.transpose(data)
print(tcga_input.shape[1])
length1 = tcga_input.shape[1]
learning_rate = 0.00000001
training_epochs = 100
batch_size = 125
display_step = 1
examples_to_show = 10
n_input = tcga_input.shape[1]
# Out:
# 1000

# %%
X = tf.placeholder("float", [None, n_input])  
  

n_hidden_1 = 200
n_hidden_2 = 50
n_hidden_3 = 2

# %%
weights = {  
    'encoder_h1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),  
    'encoder_h2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'encoder_h3': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_3])),
    'decoder_h1': tf.Variable(tf.random_normal([n_hidden_3, n_hidden_2])),
    'decoder_h2': tf.Variable(tf.random_normal([n_hidden_2, n_hidden_1])),
    'decoder_h3': tf.Variable(tf.random_normal([n_hidden_1, n_input])),


}

# %%
biases = {  
    'encoder_b1': tf.Variable(tf.random_normal([n_hidden_1])),  
    'encoder_b2': tf.Variable(tf.random_normal([n_hidden_2])),
    'encoder_b3': tf.Variable(tf.random_normal([n_hidden_3])),
    'decoder_b1': tf.Variable(tf.random_normal([n_hidden_2])),
    'decoder_b2': tf.Variable(tf.random_normal([n_hidden_1])),
    'decoder_b3': tf.Variable(tf.random_normal([n_input])),
}

# %%
def encoder(x):  
    layer_1 = tf.nn.tanh(tf.add(tf.matmul(x, weights['encoder_h1']),
                                   biases['encoder_b1']))  
    layer_2 = tf.nn.tanh(tf.add(tf.matmul(layer_1, weights['encoder_h2']),
                                   biases['encoder_b2']))
    layer_3 = tf.nn.tanh(tf.add(tf.matmul(layer_2, weights['encoder_h3']),
                                   biases['encoder_b3']))
    return layer_3

# %%
def decoder(x):  
    layer_1 = tf.nn.tanh(tf.add(tf.matmul(x, weights['decoder_h1']),
                                   biases['decoder_b1']))  
    layer_2 = tf.nn.tanh(tf.add(tf.matmul(layer_1, weights['decoder_h2']),
                                   biases['decoder_b2']))
    layer_3 = tf.nn.tanh(tf.add(tf.matmul(layer_2, weights['decoder_h3']),
                                   biases['decoder_b3']))
    return layer_3

# %%
encoder_op = encoder(X)  
decoder_op = decoder(encoder_op)

# %%
y_pred = decoder_op  
y_true = X

# %%
cost = tf.reduce_mean(tf.pow(y_true - y_pred, 2))
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %%
with tf.Session() as sess:
    if int((tf.__version__).split('.')[1]) < 12 and int((tf.__version__).split('.')[0]) < 1:  
        init = tf.initialize_all_variables()  
    else:  
        init = tf.global_variables_initializer()  
    sess.run(init)  

    total_batch = int(len(tcga_input)/batch_size)
    for epoch in range(training_epochs):  
        for i in range(total_batch):
            batch_xs = tcga_input[((i) * batch_size):((i + 1) * batch_size)] + 0.3 * np.random.rand(length1)   #added nosie
            # Run optimization op (backprop) and cost op (to get loss value)
            _, c = sess.run([optimizer, cost], feed_dict={X: batch_xs})
        if epoch % display_step == 0:  
            print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(c))
        if epoch == training_epochs - 1:
                fea_output = sess.run([encoder_op], feed_dict={X: tcga_input})
                # print(fea_output)
                print("shape of dd array :")
                print(np.array(fea_output).shape)
                np.savetxt(r'fea.csv', np.array(fea_output[0]), delimiter=',')
                dd = np.array(fea_output[0])
    print("Optimization Finished!")
    ## print(dd.shape)
    clf = KMeans(n_clusters=2)
    model = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')
    clf.fit(dd)
    model.fit(dd)
    centers = clf.cluster_centers_
    labels = clf.labels_
    labelsm = model.labels_
    silhouetteScore = silhouette_score(dd, labels, metric='euclidean')
    davies_bouldinScore = davies_bouldin_score(dd, labels)
    silhouetteScorem = silhouette_score(dd, labelsm, metric='euclidean')
    davies_bouldinScorem = davies_bouldin_score(dd, labelsm)
    print(centers)
    print("K-mean silhouette score: ",silhouetteScore)
    print("K-mean DBI: ",davies_bouldinScore)
    print("Hierarchial clustering silhouette score: ",silhouetteScorem)
    print("Hierarchial clustering DBI: ",davies_bouldinScorem)
    # encode_decode = sess.run(
    #     y_pred, feed_dict={X: mnist.test.images[:examples_to_show]})
    # f, a = plt.subplots(2, 10, figsize=(10, 2))  #return fig，axes
    # for i in range(examples_to_show):  
    #     a[0][i].imshow(np.reshape(mnist.test.images[i], (28, 28)))  
    #     a[1][i].imshow(np.reshape(encode_decode[i], (28, 28)))  
    # plt.show() 


plt.scatter(dd[:,0], dd[:,1])
# Out:
# Epoch: 0001 cost= 1.933973908
# Epoch: 0002 cost= 1.936319590
# Epoch: 0003 cost= 1.933284402
# Epoch: 0004 cost= 1.933870196
# Epoch: 0005 cost= 1.931539059
# Epoch: 0006 cost= 1.943798900
# Epoch: 0007 cost= 1.932943344
# Epoch: 0008 cost= 1.938837528
# Epoch: 0009 cost= 1.946100950
# Epoch: 0010 cost= 1.937729955
# Epoch: 0011 cost= 1.937947989
# Epoch: 0012 cost= 1.937314153
# Epoch: 0013 cost= 1.936907530
# Epoch: 0014 cost= 1.938776612
# Epoch: 0015 cost= 1.929343224
# Epoch: 0016 cost= 1.935400486
# Epoch: 0017 cost= 1.938480854
# Epoch: 0018 cost= 1.936439037
# Epoch: 0019 cost= 1.944807529
# Epoch: 0020 cost= 1.927613854
# Epoch: 0021 cost= 1.934999466
# Epoch: 0022 cost= 1.932582736
# Epoch: 0023 cost= 1.941679955
# Epoch: 0024 cost= 1.941382289
# Epoch: 0025 cost= 1.935585856
# Epoch: 0026 cost= 1.947716832
# Epoch: 0027 cost= 1.936408520
# Epoch: 0028 cost= 1.942272305
# Epoch: 0029 cost= 1.939968824
# Epoch: 0030 cost= 1.946526647
# Epoch: 0031 cost= 1.942661643
# ...
